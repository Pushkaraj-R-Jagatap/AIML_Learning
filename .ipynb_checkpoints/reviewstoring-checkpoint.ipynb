# %%
# import requests
# from bs4 import BeautifulSoup
# url=input("Enter the url")
# page=1
# headers = {
#     "User-Agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64)",
#     "Accept-Language": "en-IN,en;q=0.9",
#     "Referer": "https://www.flipkart.com/"
# }
# while True:
#     site="{}&page={}".format(url,page)
#     res=requests.get(site,headers=headers)
#     soup=BeautifulSoup(res.text,"lxml")
#     print(res)
#     review=soup.select('div.col.x_CUu6')


#     if not review:
#         print("no valid page")
#         break
#     with open(f'scraped_data/review{page}.html',"w",encoding='utf-8')as f:
#         f.write(res.text)
#         print(f"downloading the date from page no{page}")

#     page=page+1




from selenium import webdriver
from selenium.webdriver.common.by import By
from selenium.webdriver.chrome.service import Service
from webdriver_manager.chrome import ChromeDriverManager
import time

url = input("Enter Flipkart review URL: ")

driver = webdriver.Chrome(service=Service(ChromeDriverManager().install()))
driver.get(url)
time.sleep(3)

page = 1

while True:
    print(f"Saving page {page}")

    with open(f"scraped_data/review{page}.html", "w", encoding="utf-8") as f:
        f.write(driver.page_source)

    try:
        next_btn = driver.find_element(By.XPATH, "//span[text()='Next']")
        next_btn.click()
        time.sleep(3)
        page += 1
    except:
        print("No more pages")
        break

driver.quit()
# Out:
#   Cell In[82], line 28
#     pip install selenium webdriver-manager
#         ^
# SyntaxError: invalid syntax

# %%
data=[]
for i in range (1,10):
    with open(f'scraped_data/review{i}.html','r',encoding='utf-8') as f:
        html_content=f.read()
        soup=BeautifulSoup(html_content,'html.parser')
        all_info=soup.select('div.col.x_CUu6')
       

        for info in all_info:
            
            name=info.select_one('p.zJ1ZGa.ZDi3w2') 
            title= info.select_one('p.qW2QI1')
            rating= info.select_one('div.MKiFS6.ojKpP6')
            city= info.select_one('p.Zhmv6U span:nth-of-type(2)')
            Date= info.select_one('div.row p.zJ1ZGa:last-of-type')
            review= info.select_one('div.G4PxIA')
            Name=name.get_text()
            Title=title.get_text()
            Rating=rating.get_text()
            City=city.get_text()
            Month=Date.get_text()
            Review=review.get_text()
            data.append([Name,Title,Rating,City,Month,Review])
            

data
# Out:
# [['Aakash  Rathore',
#   'Good quality product',
#   '4',
#   ', Indore',
#   '5 months ago',
#   'Good phone in this price rangeREAD MORE'],
#  ['Saurabh Kumar',
#   'Highly recommended',
#   '5',
#   ', Varanasi District',
#   '5 months ago',
#   'Nice product 🥰🥰🥰READ MORE'],
#  ['Suman Naidu',
#   'Very Good',
#   '4',
#   ', Visakhapatnam',
#   '3 months ago',
#   "Mobile looks extremely good and premium. Camera quality is exceptional. Charges quickly.Drawback - battery drains quickly, despite no overuse. I basically use the phone just fr calls, what's app n social media. Slight lag is already observed. Been a month since I hv been using this phone. Good experience so far. This is the first time I switched from Samsung to Moto. If there are any issues later, I will amend my post accordinglyREAD MORE"],
#  ['Ketan Gojiya',
#   'Pretty good without Photo App',
#   '4',
#   ', Jamnagar',
#   '8 months ago',
#   'Phone is good but there is less one gallery app in the phone, its provide only google photo while no default photo/video gallery, Also phone have no cover for safety purposeREAD MORE'],
#  ['Upendra  Jaiswal',
#   'Simply awesome',
#   '5',
#   ', Hubballi',
#   '8 months ago',
#   'Everything is good but Motorola should also launch mobiles in same range without curve displayREAD MORE'],
#  ['Neeraj Sharma',
#   'Perfect product!',
#   '5',
#   ', Jaipur',
#   '8 months ago',
#   'Very good image quality 😁😍😍READ MORE'],
#  ['Vishal Pathak',
#   'Terrific purchase',
#   '5',
#   ', Adra',
#   '6 months ago',
#   'Good camera overall good phoneREAD MORE'],
#  ['Flipkart Customer',
#   'Terrific purchase',
#   '5',
#   ', Bangalore',
#   '8 months ago',
#   'One of the best phones in this price rangePros-Design- It has got a very sleek design with great looks and is light weightDisplay- Curved screen is very good with vibrant colours and crystal clear displayBattery- It has fast charging with good battery backup. Gets charged in 30-60 mins and lasts a day on regular usePerformance - Performance is good, there is some lag on heavy usageCons-Performance- There is a very slight lag on very heavy usage. Could be better in 12 gb RAM as I am us...READ MORE'],
#  ['Flipkart Customer',
#   'Best in the market!',
#   '5',
#   ', Kangayampalayam',
#   '7 months ago',
#   'Sony lytia 700 Camera is superb 🔥 Processor is also good 🎮 UI have lot of customisation 📱 ✨ Battery 🔋 backup very good 💯 4k playback and recording is brilliant ⚡Best phone in segment Problem 😞:- No back coverREAD MORE'],
#  ['Amit Patel',
#   'Nice product',
#   '4',
#   ', Allahabad',
#   '5 months ago',
#   'Nice phoneREAD MORE'],
#  ['Aakash  Rathore',
#   'Good quality product',
#   '4',
#   ', Indore',
#   '5 months ago',
#   'Good phone in this price rangeREAD MORE'],
#  ['Saurabh Kumar',
#   'Highly recommended',
#   '5',
#   ', Varanasi District',
#   '5 months ago',
#   'Nice product 🥰🥰🥰READ MORE'],
#  ['Suman Naidu',
#   'Very Good',
#   '4',
#   ', Visakhapatnam',
#   '3 months ago',
#   "Mobile looks extremely good and premium. Camera quality is exceptional. Charges quickly.Drawback - battery drains quickly, despite no overuse. I basically use the phone just fr calls, what's app n social media. Slight lag is already observed. Been a month since I hv been using this phone. Good experience so far. This is the first time I switched from Samsung to Moto. If there are any issues later, I will amend my post accordinglyREAD MORE"],
#  ['Ketan Gojiya',
#   'Pretty good without Photo App',
#   '4',
#   ', Jamnagar',
#   '8 months ago',
#   'Phone is good but there is less one gallery app in the phone, its provide only google photo while no default photo/video gallery, Also phone have no cover for safety purposeREAD MORE'],
#  ['Upendra  Jaiswal',
#   'Simply awesome',
#   '5',
#   ', Hubballi',
#   '8 months ago',
#   'Everything is good but Motorola should also launch mobiles in same range without curve displayREAD MORE'],
#  ['Neeraj Sharma',
#   'Perfect product!',
#   '5',
#   ', Jaipur',
#   '8 months ago',
#   'Very good image quality 😁😍😍READ MORE'],
#  ['Vishal Pathak',
#   'Terrific purchase',
#   '5',
#   ', Adra',
#   '6 months ago',
#   'Good camera overall good phoneREAD MORE'],
#  ['Flipkart Customer',
#   'Terrific purchase',
#   '5',
#   ', Bangalore',
#   '8 months ago',
#   'One of the best phones in this price rangePros-Design- It has got a very sleek design with great looks and is light weightDisplay- Curved screen is very good with vibrant colours and crystal clear displayBattery- It has fast charging with good battery backup. Gets charged in 30-60 mins and lasts a day on regular usePerformance - Performance is good, there is some lag on heavy usageCons-Performance- There is a very slight lag on very heavy usage. Could be better in 12 gb RAM as I am us...READ MORE'],
#  ['Flipkart Customer',
#   'Best in the market!',
#   '5',
#   ', Kangayampalayam',
#   '7 months ago',
#   'Sony lytia 700 Camera is superb 🔥 Processor is also good 🎮 UI have lot of customisation 📱 ✨ Battery 🔋 backup very good 💯 4k playback and recording is brilliant ⚡Best phone in segment Problem 😞:- No back coverREAD MORE'],
#  ['Amit Patel',
#   'Nice product',
#   '4',
#   ', Allahabad',
#   '5 months ago',
#   'Nice phoneREAD MORE'],
#  ['Aakash  Rathore',
#   'Good quality product',
#   '4',
#   ', Indore',
#   '5 months ago',
#   'Good phone in this price rangeREAD MORE'],
#  ['Saurabh Kumar',
#   'Highly recommended',
#   '5',
#   ', Varanasi District',
#   '5 months ago',
#   'Nice product 🥰🥰🥰READ MORE'],
#  ['Suman Naidu',
#   'Very Good',
#   '4',
#   ', Visakhapatnam',
#   '3 months ago',
#   "Mobile looks extremely good and premium. Camera quality is exceptional. Charges quickly.Drawback - battery drains quickly, despite no overuse. I basically use the phone just fr calls, what's app n social media. Slight lag is already observed. Been a month since I hv been using this phone. Good experience so far. This is the first time I switched from Samsung to Moto. If there are any issues later, I will amend my post accordinglyREAD MORE"],
#  ['Ketan Gojiya',
#   'Pretty good without Photo App',
#   '4',
#   ', Jamnagar',
#   '8 months ago',
#   'Phone is good but there is less one gallery app in the phone, its provide only google photo while no default photo/video gallery, Also phone have no cover for safety purposeREAD MORE'],
#  ['Upendra  Jaiswal',
#   'Simply awesome',
#   '5',
#   ', Hubballi',
#   '8 months ago',
#   'Everything is good but Motorola should also launch mobiles in same range without curve displayREAD MORE'],
#  ['Neeraj Sharma',
#   'Perfect product!',
#   '5',
#   ', Jaipur',
#   '8 months ago',
#   'Very good image quality 😁😍😍READ MORE'],
#  ['Vishal Pathak',
#   'Terrific purchase',
#   '5',
#   ', Adra',
#   '6 months ago',
#   'Good camera overall good phoneREAD MORE'],
#  ['Flipkart Customer',
#   'Terrific purchase',
#   '5',
#   ', Bangalore',
#   '8 months ago',
#   'One of the best phones in this price rangePros-Design- It has got a very sleek design with great looks and is light weightDisplay- Curved screen is very good with vibrant colours and crystal clear displayBattery- It has fast charging with good battery backup. Gets charged in 30-60 mins and lasts a day on regular usePerformance - Performance is good, there is some lag on heavy usageCons-Performance- There is a very slight lag on very heavy usage. Could be better in 12 gb RAM as I am us...READ MORE'],
#  ['Flipkart Customer',
#   'Best in the market!',
#   '5',
#   ', Kangayampalayam',
#   '7 months ago',
#   'Sony lytia 700 Camera is superb 🔥 Processor is also good 🎮 UI have lot of customisation 📱 ✨ Battery 🔋 backup very good 💯 4k playback and recording is brilliant ⚡Best phone in segment Problem 😞:- No back coverREAD MORE'],
#  ['Amit Patel',
#   'Nice product',
#   '4',
#   ', Allahabad',
#   '5 months ago',
#   'Nice phoneREAD MORE'],
#  ['Aakash  Rathore',
#   'Good quality product',
#   '4',
#   ', Indore',
#   '5 months ago',
#   'Good phone in this price rangeREAD MORE'],
#  ['Saurabh Kumar',
#   'Highly recommended',
#   '5',
#   ', Varanasi District',
#   '5 months ago',
#   'Nice product 🥰🥰🥰READ MORE'],
#  ['Suman Naidu',
#   'Very Good',
#   '4',
#   ', Visakhapatnam',
#   '3 months ago',
#   "Mobile looks extremely good and premium. Camera quality is exceptional. Charges quickly.Drawback - battery drains quickly, despite no overuse. I basically use the phone just fr calls, what's app n social media. Slight lag is already observed. Been a month since I hv been using this phone. Good experience so far. This is the first time I switched from Samsung to Moto. If there are any issues later, I will amend my post accordinglyREAD MORE"],
#  ['Ketan Gojiya',
#   'Pretty good without Photo App',
#   '4',
#   ', Jamnagar',
#   '8 months ago',
#   'Phone is good but there is less one gallery app in the phone, its provide only google photo while no default photo/video gallery, Also phone have no cover for safety purposeREAD MORE'],
#  ['Upendra  Jaiswal',
#   'Simply awesome',
#   '5',
#   ', Hubballi',
#   '8 months ago',
#   'Everything is good but Motorola should also launch mobiles in same range without curve displayREAD MORE'],
#  ['Neeraj Sharma',
#   'Perfect product!',
#   '5',
#   ', Jaipur',
#   '8 months ago',
#   'Very good image quality 😁😍😍READ MORE'],
#  ['Vishal Pathak',
#   'Terrific purchase',
#   '5',
#   ', Adra',
#   '6 months ago',
#   'Good camera overall good phoneREAD MORE'],
#  ['Flipkart Customer',
#   'Terrific purchase',
#   '5',
#   ', Bangalore',
#   '8 months ago',
#   'One of the best phones in this price rangePros-Design- It has got a very sleek design with great looks and is light weightDisplay- Curved screen is very good with vibrant colours and crystal clear displayBattery- It has fast charging with good battery backup. Gets charged in 30-60 mins and lasts a day on regular usePerformance - Performance is good, there is some lag on heavy usageCons-Performance- There is a very slight lag on very heavy usage. Could be better in 12 gb RAM as I am us...READ MORE'],
#  ['Flipkart Customer',
#   'Best in the market!',
#   '5',
#   ', Kangayampalayam',
#   '7 months ago',
#   'Sony lytia 700 Camera is superb 🔥 Processor is also good 🎮 UI have lot of customisation 📱 ✨ Battery 🔋 backup very good 💯 4k playback and recording is brilliant ⚡Best phone in segment Problem 😞:- No back coverREAD MORE'],
#  ['Amit Patel',
#   'Nice product',
#   '4',
#   ', Allahabad',
#   '5 months ago',
#   'Nice phoneREAD MORE'],
#  ['Aakash  Rathore',
#   'Good quality product',
#   '4',
#   ', Indore',
#   '5 months ago',
#   'Good phone in this price rangeREAD MORE'],
#  ['Saurabh Kumar',
#   'Highly recommended',
#   '5',
#   ', Varanasi District',
#   '5 months ago',
#   'Nice product 🥰🥰🥰READ MORE'],
#  ['Suman Naidu',
#   'Very Good',
#   '4',
#   ', Visakhapatnam',
#   '3 months ago',
#   "Mobile looks extremely good and premium. Camera quality is exceptional. Charges quickly.Drawback - battery drains quickly, despite no overuse. I basically use the phone just fr calls, what's app n social media. Slight lag is already observed. Been a month since I hv been using this phone. Good experience so far. This is the first time I switched from Samsung to Moto. If there are any issues later, I will amend my post accordinglyREAD MORE"],
#  ['Ketan Gojiya',
#   'Pretty good without Photo App',
#   '4',
#   ', Jamnagar',
#   '8 months ago',
#   'Phone is good but there is less one gallery app in the phone, its provide only google photo while no default photo/video gallery, Also phone have no cover for safety purposeREAD MORE'],
#  ['Upendra  Jaiswal',
#   'Simply awesome',
#   '5',
#   ', Hubballi',
#   '8 months ago',
#   'Everything is good but Motorola should also launch mobiles in same range without curve displayREAD MORE'],
#  ['Neeraj Sharma',
#   'Perfect product!',
#   '5',
#   ', Jaipur',
#   '8 months ago',
#   'Very good image quality 😁😍😍READ MORE'],
#  ['Vishal Pathak',
#   'Terrific purchase',
#   '5',
#   ', Adra',
#   '6 months ago',
#   'Good camera overall good phoneREAD MORE'],
#  ['Flipkart Customer',
#   'Terrific purchase',
#   '5',
#   ', Bangalore',
#   '8 months ago',
#   'One of the best phones in this price rangePros-Design- It has got a very sleek design with great looks and is light weightDisplay- Curved screen is very good with vibrant colours and crystal clear displayBattery- It has fast charging with good battery backup. Gets charged in 30-60 mins and lasts a day on regular usePerformance - Performance is good, there is some lag on heavy usageCons-Performance- There is a very slight lag on very heavy usage. Could be better in 12 gb RAM as I am us...READ MORE'],
#  ['Flipkart Customer',
#   'Best in the market!',
#   '5',
#   ', Kangayampalayam',
#   '7 months ago',
#   'Sony lytia 700 Camera is superb 🔥 Processor is also good 🎮 UI have lot of customisation 📱 ✨ Battery 🔋 backup very good 💯 4k playback and recording is brilliant ⚡Best phone in segment Problem 😞:- No back coverREAD MORE'],
#  ['Amit Patel',
#   'Nice product',
#   '4',
#   ', Allahabad',
#   '5 months ago',
#   'Nice phoneREAD MORE'],
#  ['Aakash  Rathore',
#   'Good quality product',
#   '4',
#   ', Indore',
#   '5 months ago',
#   'Good phone in this price rangeREAD MORE'],
#  ['Saurabh Kumar',
#   'Highly recommended',
#   '5',
#   ', Varanasi District',
#   '5 months ago',
#   'Nice product 🥰🥰🥰READ MORE'],
#  ['Suman Naidu',
#   'Very Good',
#   '4',
#   ', Visakhapatnam',
#   '3 months ago',
#   "Mobile looks extremely good and premium. Camera quality is exceptional. Charges quickly.Drawback - battery drains quickly, despite no overuse. I basically use the phone just fr calls, what's app n social media. Slight lag is already observed. Been a month since I hv been using this phone. Good experience so far. This is the first time I switched from Samsung to Moto. If there are any issues later, I will amend my post accordinglyREAD MORE"],
#  ['Ketan Gojiya',
#   'Pretty good without Photo App',
#   '4',
#   ', Jamnagar',
#   '8 months ago',
#   'Phone is good but there is less one gallery app in the phone, its provide only google photo while no default photo/video gallery, Also phone have no cover for safety purposeREAD MORE'],
#  ['Upendra  Jaiswal',
#   'Simply awesome',
#   '5',
#   ', Hubballi',
#   '8 months ago',
#   'Everything is good but Motorola should also launch mobiles in same range without curve displayREAD MORE'],
#  ['Neeraj Sharma',
#   'Perfect product!',
#   '5',
#   ', Jaipur',
#   '8 months ago',
#   'Very good image quality 😁😍😍READ MORE'],
#  ['Vishal Pathak',
#   'Terrific purchase',
#   '5',
#   ', Adra',
#   '6 months ago',
#   'Good camera overall good phoneREAD MORE'],
#  ['Flipkart Customer',
#   'Terrific purchase',
#   '5',
#   ', Bangalore',
#   '8 months ago',
#   'One of the best phones in this price rangePros-Design- It has got a very sleek design with great looks and is light weightDisplay- Curved screen is very good with vibrant colours and crystal clear displayBattery- It has fast charging with good battery backup. Gets charged in 30-60 mins and lasts a day on regular usePerformance - Performance is good, there is some lag on heavy usageCons-Performance- There is a very slight lag on very heavy usage. Could be better in 12 gb RAM as I am us...READ MORE'],
#  ['Flipkart Customer',
#   'Best in the market!',
#   '5',
#   ', Kangayampalayam',
#   '7 months ago',
#   'Sony lytia 700 Camera is superb 🔥 Processor is also good 🎮 UI have lot of customisation 📱 ✨ Battery 🔋 backup very good 💯 4k playback and recording is brilliant ⚡Best phone in segment Problem 😞:- No back coverREAD MORE'],
#  ['Amit Patel',
#   'Nice product',
#   '4',
#   ', Allahabad',
#   '5 months ago',
#   'Nice phoneREAD MORE'],
#  ['Aakash  Rathore',
#   'Good quality product',
#   '4',
#   ', Indore',
#   '5 months ago',
#   'Good phone in this price rangeREAD MORE'],
#  ['Saurabh Kumar',
#   'Highly recommended',
#   '5',
#   ', Varanasi District',
#   '5 months ago',
#   'Nice product 🥰🥰🥰READ MORE'],
#  ['Suman Naidu',
#   'Very Good',
#   '4',
#   ', Visakhapatnam',
#   '3 months ago',
#   "Mobile looks extremely good and premium. Camera quality is exceptional. Charges quickly.Drawback - battery drains quickly, despite no overuse. I basically use the phone just fr calls, what's app n social media. Slight lag is already observed. Been a month since I hv been using this phone. Good experience so far. This is the first time I switched from Samsung to Moto. If there are any issues later, I will amend my post accordinglyREAD MORE"],
#  ['Ketan Gojiya',
#   'Pretty good without Photo App',
#   '4',
#   ', Jamnagar',
#   '8 months ago',
#   'Phone is good but there is less one gallery app in the phone, its provide only google photo while no default photo/video gallery, Also phone have no cover for safety purposeREAD MORE'],
#  ['Upendra  Jaiswal',
#   'Simply awesome',
#   '5',
#   ', Hubballi',
#   '8 months ago',
#   'Everything is good but Motorola should also launch mobiles in same range without curve displayREAD MORE'],
#  ['Neeraj Sharma',
#   'Perfect product!',
#   '5',
#   ', Jaipur',
#   '8 months ago',
#   'Very good image quality 😁😍😍READ MORE'],
#  ['Vishal Pathak',
#   'Terrific purchase',
#   '5',
#   ', Adra',
#   '6 months ago',
#   'Good camera overall good phoneREAD MORE'],
#  ['Flipkart Customer',
#   'Terrific purchase',
#   '5',
#   ', Bangalore',
#   '8 months ago',
#   'One of the best phones in this price rangePros-Design- It has got a very sleek design with great looks and is light weightDisplay- Curved screen is very good with vibrant colours and crystal clear displayBattery- It has fast charging with good battery backup. Gets charged in 30-60 mins and lasts a day on regular usePerformance - Performance is good, there is some lag on heavy usageCons-Performance- There is a very slight lag on very heavy usage. Could be better in 12 gb RAM as I am us...READ MORE'],
#  ['Flipkart Customer',
#   'Best in the market!',
#   '5',
#   ', Kangayampalayam',
#   '7 months ago',
#   'Sony lytia 700 Camera is superb 🔥 Processor is also good 🎮 UI have lot of customisation 📱 ✨ Battery 🔋 backup very good 💯 4k playback and recording is brilliant ⚡Best phone in segment Problem 😞:- No back coverREAD MORE'],
#  ['Amit Patel',
#   'Nice product',
#   '4',
#   ', Allahabad',
#   '5 months ago',
#   'Nice phoneREAD MORE'],
#  ['Aakash  Rathore',
#   'Good quality product',
#   '4',
#   ', Indore',
#   '5 months ago',
#   'Good phone in this price rangeREAD MORE'],
#  ['Saurabh Kumar',
#   'Highly recommended',
#   '5',
#   ', Varanasi District',
#   '5 months ago',
#   'Nice product 🥰🥰🥰READ MORE'],
#  ['Suman Naidu',
#   'Very Good',
#   '4',
#   ', Visakhapatnam',
#   '3 months ago',
#   "Mobile looks extremely good and premium. Camera quality is exceptional. Charges quickly.Drawback - battery drains quickly, despite no overuse. I basically use the phone just fr calls, what's app n social media. Slight lag is already observed. Been a month since I hv been using this phone. Good experience so far. This is the first time I switched from Samsung to Moto. If there are any issues later, I will amend my post accordinglyREAD MORE"],
#  ['Ketan Gojiya',
#   'Pretty good without Photo App',
#   '4',
#   ', Jamnagar',
#   '8 months ago',
#   'Phone is good but there is less one gallery app in the phone, its provide only google photo while no default photo/video gallery, Also phone have no cover for safety purposeREAD MORE'],
#  ['Upendra  Jaiswal',
#   'Simply awesome',
#   '5',
#   ', Hubballi',
#   '8 months ago',
#   'Everything is good but Motorola should also launch mobiles in same range without curve displayREAD MORE'],
#  ['Neeraj Sharma',
#   'Perfect product!',
#   '5',
#   ', Jaipur',
#   '8 months ago',
#   'Very good image quality 😁😍😍READ MORE'],
#  ['Vishal Pathak',
#   'Terrific purchase',
#   '5',
#   ', Adra',
#   '6 months ago',
#   'Good camera overall good phoneREAD MORE'],
#  ['Flipkart Customer',
#   'Terrific purchase',
#   '5',
#   ', Bangalore',
#   '8 months ago',
#   'One of the best phones in this price rangePros-Design- It has got a very sleek design with great looks and is light weightDisplay- Curved screen is very good with vibrant colours and crystal clear displayBattery- It has fast charging with good battery backup. Gets charged in 30-60 mins and lasts a day on regular usePerformance - Performance is good, there is some lag on heavy usageCons-Performance- There is a very slight lag on very heavy usage. Could be better in 12 gb RAM as I am us...READ MORE'],
#  ['Flipkart Customer',
#   'Best in the market!',
#   '5',
#   ', Kangayampalayam',
#   '7 months ago',
#   'Sony lytia 700 Camera is superb 🔥 Processor is also good 🎮 UI have lot of customisation 📱 ✨ Battery 🔋 backup very good 💯 4k playback and recording is brilliant ⚡Best phone in segment Problem 😞:- No back coverREAD MORE'],
#  ['Amit Patel',
#   'Nice product',
#   '4',
#   ', Allahabad',
#   '5 months ago',
#   'Nice phoneREAD MORE'],
#  ['Aakash  Rathore',
#   'Good quality product',
#   '4',
#   ', Indore',
#   '5 months ago',
#   'Good phone in this price rangeREAD MORE'],
#  ['Saurabh Kumar',
#   'Highly recommended',
#   '5',
#   ', Varanasi District',
#   '5 months ago',
#   'Nice product 🥰🥰🥰READ MORE'],
#  ['Suman Naidu',
#   'Very Good',
#   '4',
#   ', Visakhapatnam',
#   '3 months ago',
#   "Mobile looks extremely good and premium. Camera quality is exceptional. Charges quickly.Drawback - battery drains quickly, despite no overuse. I basically use the phone just fr calls, what's app n social media. Slight lag is already observed. Been a month since I hv been using this phone. Good experience so far. This is the first time I switched from Samsung to Moto. If there are any issues later, I will amend my post accordinglyREAD MORE"],
#  ['Ketan Gojiya',
#   'Pretty good without Photo App',
#   '4',
#   ', Jamnagar',
#   '8 months ago',
#   'Phone is good but there is less one gallery app in the phone, its provide only google photo while no default photo/video gallery, Also phone have no cover for safety purposeREAD MORE'],
#  ['Upendra  Jaiswal',
#   'Simply awesome',
#   '5',
#   ', Hubballi',
#   '8 months ago',
#   'Everything is good but Motorola should also launch mobiles in same range without curve displayREAD MORE'],
#  ['Neeraj Sharma',
#   'Perfect product!',
#   '5',
#   ', Jaipur',
#   '8 months ago',
#   'Very good image quality 😁😍😍READ MORE'],
#  ['Vishal Pathak',
#   'Terrific purchase',
#   '5',
#   ', Adra',
#   '6 months ago',
#   'Good camera overall good phoneREAD MORE'],
#  ['Flipkart Customer',
#   'Terrific purchase',
#   '5',
#   ', Bangalore',
#   '8 months ago',
#   'One of the best phones in this price rangePros-Design- It has got a very sleek design with great looks and is light weightDisplay- Curved screen is very good with vibrant colours and crystal clear displayBattery- It has fast charging with good battery backup. Gets charged in 30-60 mins and lasts a day on regular usePerformance - Performance is good, there is some lag on heavy usageCons-Performance- There is a very slight lag on very heavy usage. Could be better in 12 gb RAM as I am us...READ MORE'],
#  ['Flipkart Customer',
#   'Best in the market!',
#   '5',
#   ', Kangayampalayam',
#   '7 months ago',
#   'Sony lytia 700 Camera is superb 🔥 Processor is also good 🎮 UI have lot of customisation 📱 ✨ Battery 🔋 backup very good 💯 4k playback and recording is brilliant ⚡Best phone in segment Problem 😞:- No back coverREAD MORE'],
#  ['Amit Patel',
#   'Nice product',
#   '4',
#   ', Allahabad',
#   '5 months ago',
#   'Nice phoneREAD MORE']]

# %%
data
import pandas as pd
table=pd.DataFrame(data)
table.to_csv("scraped_data/flipkartreview.csv",index=False)
df=pd.read_csv("scraped_data/flipkartreview.csv")
df
# Out:
#                     0                              1  2                    3  \
# 0     Aakash  Rathore           Good quality product  4             , Indore
# 1       Saurabh Kumar             Highly recommended  5  , Varanasi District
# 2         Suman Naidu                      Very Good  4      , Visakhapatnam
# 3        Ketan Gojiya  Pretty good without Photo App  4           , Jamnagar
# 4    Upendra  Jaiswal                 Simply awesome  5           , Hubballi
# ..                ...                            ... ..                  ...
# 85      Neeraj Sharma               Perfect product!  5             , Jaipur
# 86      Vishal Pathak              Terrific purchase  5               , Adra
# 87  Flipkart Customer              Terrific purchase  5          , Bangalore
# 88  Flipkart Customer            Best in the market!  5    , Kangayampalayam
# 89         Amit Patel                   Nice product  4          , Allahabad
#
#                4                                                  5
# 0   5 months ago            Good phone in this price rangeREAD MORE
# 1   5 months ago                          Nice product 🥰🥰🥰READ MORE
# 2   3 months ago  Mobile looks extremely good and premium. Camer...
# 3   8 months ago  Phone is good but there is less one gallery ap...
# 4   8 months ago  Everything is good but Motorola should also la...
# ..           ...                                                ...
# 85  8 months ago               Very good image quality 😁😍😍READ MORE
# 86  6 months ago            Good camera overall good phoneREAD MORE
# 87  8 months ago  One of the best phones in this price rangePros...
# 88  7 months ago  Sony lytia 700 Camera is superb 🔥 Processor is...
# 89  5 months ago                                Nice phoneREAD MORE
#
# [90 rows x 6 columns]
