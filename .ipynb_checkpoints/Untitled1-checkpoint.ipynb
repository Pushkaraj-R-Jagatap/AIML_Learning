# %%
import requests
from bs4 import BeautifulSoup
page=1
while True:
    url=f"https://quotes.toscrape.com/page/{page}/"
    res=requests.get(url)
    soup=BeautifulSoup(res.text,"lxml")
    quotes=soup.select('div.quote')
 

    if not quotes:
        print("no valid page")
        break
    with open(f"scraped_data/page{page}.html","w",encoding="utf-8")as f:
        f.write(res.text)
        print(f"downloaded the data from page{page}")
    page=page+1
# Out:
# downloaded the data from page1
# downloaded the data from page2
# downloaded the data from page3
# downloaded the data from page4
# downloaded the data from page5
# downloaded the data from page6
# downloaded the data from page7
# downloaded the data from page8
# downloaded the data from page9
# downloaded the data from page10
# no valid page

# %%
# for i in range(1,11):
    # with open(f"scraped_data/page{i}.html","r",encoding="utf-8") as f:
    #      html_content=f.read()
    #      soup=BeautifulSoup(html_content)
all_html = []      # store raw HTML
# all_soups = []     # store parsed HTML
all_tags=[]
data=[]
for i in range(1, 11):
    with open(f"scraped_data/page{i}.html", "r", encoding="utf-8") as f:
        html_content = f.read()
        all_html.append(html_content)
        soup.append(BeautifulSoup(html_content, "html.parser"))

        all_quotes=soup.select("div.quote")

        for q in all_quotes:
            for tag in q.select(".tags .tag"):
                 all_tags.append(tag.get_text())
            if "life" in all_tags:
                text=q.select_one("span.text").get_text(strip=True)
                author=q.select_one("small.author").get_text(strip=True)
                data.append([text,author])

# %%
data
import pandas as pd
table=pd.DataFrame(data)
table.to_csv("scraped_data/table.csv",index=False)
df=pd.read_csv("scraped_data/table.csv")
df
# Out:
#                                                       0                   1
# 0     “There are only two ways to live your life. On...     Albert Einstein
# 1     “The person, be it gentleman or lady, who has ...         Jane Austen
# 2     “Imperfection is beauty, madness is genius and...      Marilyn Monroe
# 3     “Try not to become a man of success. Rather be...     Albert Einstein
# 4     “It is better to be hated for what you are tha...          André Gide
# ...                                                 ...                 ...
# 3743  “You never really understand a person until yo...          Harper Lee
# 3744  “You have to write the book that wants to be w...   Madeleine L'Engle
# 3745  “Never tell the truth to people who are not wo...          Mark Twain
# 3746        “A person's a person, no matter how small.”           Dr. Seuss
# 3747  “... a mind needs books as a sword needs a whe...  George R.R. Martin
#
# [3748 rows x 2 columns]
